# %% [markdown]
# # 95/20 Ranking
#
# Estimate top-coded incomes from PUMs data. It sounds like we should pull with a PUMA instead of MET2013, and translate the geography in the analysis.

# %%
import pandas

ct_census = pandas.read_csv("too_big/ss14hct.csv") ## Grab for every topcoded state

pums = pandas.read_csv("too_big/usa_00002.csv")
acs_14 = pandas.read_csv("hh_14.csv",encoding = "ISO-8859-1")

# %%
census_vars_ct = ["PUMA","ADJINC","SERIALNO","HINCP","WGTP", "PUMA"]
census_vars = ["PUMA","ADJINC","SERIALNO","HINCP","WGTP", "stpuma"]

#bridgeport_pumas = ["00100", "00101", "00102", "00103", "00104", "00105"]

ct_census["bridgeport"] = ct_census["PUMA"].apply(lambda x: ((x>=100) & (x<=105)))

bridgeport_2014 = ct_census[ct_census["bridgeport"]==True][census_vars_ct]
bridgeport_2014["HHINC"] = pandas.to_numeric(bridgeport_2014["HINCP"],errors="coerce")
bridgeport_2014["ADJHH"] = bridgeport_2014.apply(lambda x: (x["ADJINC"]/1000000)*x["HHINC"], axis=1)

# %%
def multiply(row,income_col,weight_col,puma_col,tar):
    i = 0
    while i < row[weight_col]:
        new = {puma_col:row[puma_col],income_col:row[income_col]}
        tar.append(new)
        i+=1

def explode_weights(df,income_col, weight_col,puma_col):
    ## Make a list of HHINCOME for calculating
    ## a quantile where each household's HHINCOME
    ## is repeated in the series n times, where
    ## n == weight_col
    tar = []
    df.apply(lambda x: multiply(x,income_col,weight_col,puma_col,tar),axis=1)
    return tar

exploded_bridgeport = explode_weights(bridgeport_2014,"ADJHH","WGTP","PUMA")

# %%
pandas.DataFrame(exploded_bridgeport)["ADJHH"].quantile(.95, interpolation="lower")
# Out:
# 558969.9774999999

# %% [markdown]
# # Hallelujah!
#
# This is the number Brookings had! But from talking to the Census it sounds like they were wrong to adjust income to constant dollars, so we won't do that for our analysis:

# %%
exploded_bridgeport = explode_weights(bridgeport_2014,"HHINC","WGTP",'PUMA')
pandas.DataFrame(exploded_bridgeport)["HHINC"].quantile(.95)
# Out:
# 554300.0

# %% [markdown]
# ### Calculate all topcoded 95th percentiles
#
# Load:
#
# * The ACS quantile cut-offs for 2016
# * The latest GeoCorr mappings within states containing top-coded CBSAs -- between CBSA & PUMAs
#
# Filter down to just those missing 95th percentile numbers (there are no 'bottom-coded' numbers missing at the 20th percentile)

# %%
acs_16 = pandas.read_csv("hh_16.csv", encoding = "ISO-8859-1")
mable = pandas.read_csv("geocorr15.csv", encoding = "ISO-8859-1")[1:]

top_coded = acs_16[acs_16["HD01_VD06"].isnull()]
bottom_coded = acs_16[acs_16["HD01_VD02"].isnull()]

top_coded["States"] = top_coded["GEO.display-label"].apply(lambda x: x.split(',')[1].split()[0].split('-'))
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %% [markdown]
# PUMAs are unique within states but not nationally. To handle this, I made my own geography -- STPUMA -- id by concatenating the state's FIPs code with the PUMA.

# %%
def digit_str(i,digits):
    s = str(i)
    fill = digits - len(s)
    j = 0
    while j < fill:
        s = '0'+s
        j += 1
    return s

def make_stpuma(st,puma):
    s_puma = digit_str(puma,5)
    return int(str(st)+s_puma)

make_stpuma(9,102)
# Out:
# 900102

# %%
## Keeping this around/maintained as an error-check that everything is working properly
ct_census['stpuma'] = ct_census.apply(lambda x: make_stpuma(x["ST"],x["PUMA"]),axis=1)

# %%
mable['stpuma'] = mable.apply(lambda x: make_stpuma(x["state"],x["puma12"]),axis=1)
mable.head()
# Out:
#   state puma12   cbsa stab                                 cbsaname15  \
# 1    06  00101  41860   CA  San Francisco-Oakland-Hayward, CA (Metro)
# 2    06  00102  41860   CA  San Francisco-Oakland-Hayward, CA (Metro)
# 3    06  00103  41860   CA  San Francisco-Oakland-Hayward, CA (Metro)
# 4    06  00104  41860   CA  San Francisco-Oakland-Hayward, CA (Metro)
# 5    06  00105  41860   CA  San Francisco-Oakland-Hayward, CA (Metro)
#
#                                             PUMAname   pop10 afact  stpuma
# 1   Alameda County (North)--Berkeley & Albany Cities  131119    1   600101
# 2  Alameda County (Northwest)--Oakland (Northwest...  158091    1   600102
# 3  Alameda County (Northeast)--Oakland (East) & P...  125229    1   600103
# 4  Alameda County (North Central)--Oakland City (...  124608    1   600104
# 5  Alameda County (West)--San Leandro, Alameda & ...  163534    1   600105

# %% [markdown]
# Go through the topcoded CBSAs, and search the geocorr table for the contingentst pumas. The table also contains a percentage number for how much of the STPUMA is within the CBSA. I store those in a column containing dicts where the keys are the STPUMAs and the values are the percentages.

# %%
mable["cbsa"] = mable["cbsa"].apply(lambda x : pandas.to_numeric(x,errors="coerce"))
all_pumas = []

def get_pumas(geo_id,geo_corr):
    cbsa = geo_corr[geo_corr["cbsa"] == geo_id] 
    if len(cbsa) == 0:
        print(geo_id)
    target = {}
    for index,row in cbsa.iterrows():
        target[int(row["stpuma"])] = float(row["afact"])
        all_pumas.append(int(row["stpuma"]))
    return target

top_coded["PUMAS"] = top_coded["GEO.id2"].apply(lambda x: get_pumas(x,mable))
# Out:
# 640354
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
state_fips = mable.groupby("stab")[['state']].max()
state_fips.loc["CA"]["state"]
# Out:
# '06'

# %% [markdown]
# Functions for fetching the PUMS census files, unzipping them, and storing them in a local file structure. I also process them a bit -- notably by making a STPUMA field -- and then store the all the PUMS entries in a single data frame, which the function get_census_pums returns.
#
# Links to the files can be found on this page: https://factfinder.census.gov/faces/tableservices/jsf/pages/productview.xhtml?pid=ACS_pums_csv_2016&prodType=document

# %%
import zipfile,requests,io,os

def fetch_census(x):
    zip_path = "https://www2.census.gov/programs-surveys/acs/data/pums/2016/1-Year/csv_h"+x+".zip"
    r = requests.get(zip_path, stream=True)
    zip_ref = zipfile.ZipFile(io.BytesIO(r.content))
    dir_path = "too_big/2016/csv_h"+x+"/"
    zip_ref.extractall(dir_path)
    os.remove("too_big/2016/csv_h"+x+"/ACS2016_PUMS_README.pdf")

def download_unzip_census(ss_s):
    ss_s.apply(lambda x: fetch_census(x.lower()))
    
def make_path(year,state):
    return ("too_big/"+str(year)+"/csv_h"+state+"/ss16h"+state+".csv")
    
def get_census_pums(ss_s,model):
    tar = pandas.DataFrame(columns=model.columns)
    for index, s in ss_s.iteritems():
        file = make_path("year",s.lower())
        new = pandas.read_csv(file) ## Grab for every topcoded state
        statefip = state_fips.loc[s]["state"]
        new["stpuma"] = new.apply(lambda x: make_stpuma(x["ST"],x["PUMA"]),axis=1)
        tar = pandas.concat([tar,new])
    return tar

# %%
import pickle

# Chris, I didn't end up using your pickle code, but did run with the idea. 
# I think that each cell is executable whether or not you have the pickles I've cached.

def write_obj(obj,filename):
    with open(filename, 'wb') as handle:
        pickle.dump(obj, handle, protocol=pickle.HIGHEST_PROTOCOL)

def load_obj(filename):
    with open(filename, 'rb') as handle:
        b = pickle.load(handle)
        return b

# %% [markdown]
# If the PUMs data exploded by weight is available in a pickle, pull that. Otherwise, fetch the PUMS data from all the states that contain topcoded CBSAs, or parts of them. Filter for only stpumas that are part of our topcoded CBSAs. Make a numeric household income column HHINC, then convert the data (exploded_weights) so that each household is listed n times where n = WGTP (the household's weight field). Get that as 'exploded_census'

# %%
def pums_dataset(tc):
    if (os.path.isfile("too_big/exploded_census.pickle")):
        return load_obj("too_big/exploded_census.pickle")
    else:
        s = pandas.Series(tc["States"].sum()).drop_duplicates().sort_values()
        s = s[s!="California"]
        if not (os.path.isfile("too_big/2016/csv_hco/ss16hco.csv")):
            download_unzip_census(s)
        census_pums = get_census_pums(s,ct_census)
        census_pums["relevant"] = census_pums["stpuma"].apply(lambda x: x in all_pumas)
        relevant_census = census_pums[census_pums["relevant"]]
        relevant_census["HHINC"] = pandas.to_numeric(relevant_census["HINCP"],errors="coerce")
        exploded_census = explode_weights(relevant_census,"HHINC","WGTP","stpuma")
        write_obj(exploded_census,"too_big/exploded_census.pickle")
        return exploded_census

exploded_census = pums_dataset(top_coded)
exploded_census = pandas.DataFrame(exploded_census)

# %%
def count(x):
    if "Metro" in x:
        return True
    else:
        return False
    
top_coded["count"] = top_coded["GEO.display-label"].apply(lambda x: ("Metro" in x))
sample = top_coded[top_coded["count"]]    

x = [['puma','afac']]
for index,value in sample["PUMAS"].iteritems():
    for entry in value:
        x.append([entry,value[entry]])
        
df = pandas.DataFrame(x[1:],columns=x[0])
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys

# %%
df.groupby(df['afac']<1).count()
# Out:
#        puma  afac
# afac
# False   380   380
# True     20    20

# %% [markdown]
# Go through all the topcoded CBSAs, and then construct unweighted/exploded PUMs data for each of them by pulling the appropriate percentage of each component PUMA. (It's possible that income isn't evenly distributed through a PUMA geographically. BUT: This is equivalent to how Brookings did it, and accounts for a very small percentage of the data, and 0 of the Bridgeport-Stamford-Connecticut number.)
#
# Store the constructed data sets in a dict, where the keys are the CBSA's GEO.id2, and the values are the data we've constructed for them.

# %%
def get_data(puma,percent,census):
    all_entries = census[census["stpuma"]==puma]
    if percent < 1: 
        s = all_entries.sample(frac=percent,random_state=0)
        return(s)
    return(all_entries)
    
def make_fips_data_dict(df,census):
    if (os.path.isfile("too_big/fips_dict.pickle")):
        return load_obj("too_big/fips_dict.pickle")
    else:
        d = {}
        for index, row in df.iterrows():
            tar = pandas.DataFrame(columns=census.columns)
            fip = row["GEO.id2"]
            pumas = row["PUMAS"]
            for p in pumas:
                new = get_data(p,pumas[p],census)
                tar = pandas.concat([tar,new])
            d[fip] = tar
        write_obj(d,"too_big/fips_dict.pickle")
        return d
    
fips_data_dict = make_fips_data_dict(top_coded,exploded_census)

# %%
fips_data_dict[14860]["HHINC"].quantile(.95)
# Out:
# 482000.0

# %% [markdown]
# Then calculating quantile is as easy as using the pandas quantile function for each CBSA's constructed dataset:

# %%
def get_quantile(fips,percent,d):
    data = d[fips]
    return(data["HHINC"].quantile(percent))

top_coded["95_Percentile"] = top_coded["GEO.id2"].apply(lambda x: get_quantile(x,.95,fips_data_dict))
top_coded["20_Percentile"] = top_coded["GEO.id2"].apply(lambda x: get_quantile(x,.2,fips_data_dict))
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
top_coded
# Out:
#                GEO.id  GEO.id2  \
# 0    1600000US0640354   640354
# 109    310M300US14460    14460
# 110    310M300US14500    14500
# 120    310M300US14860    14860
# 259    310M300US20780    20780
# 417    310M300US27220    27220
# 506    310M300US31060    31060
# 507    310M300US31080    31080
# 563    310M300US33260    33260
# 601    310M300US34900    34900
# 602    310M300US34940    34940
# 617    310M300US35620    35620
# 655    310M300US37100    37100
# 766    310M300US41860    41860
# 768    310M300US41940    41940
# 771    310M300US42100    42100
# 838    310M300US44920    44920
# 863    310M300US45940    45940
# 891    310M300US47240    47240
# 905    310M300US47900    47900
# 924    310M300US48780    48780
#
#                                      GEO.display-label  HD01_VD02  HD02_VD02  \
# 0                           La Quinta city, California    27794.0     2167.0
# 109          Boston-Cambridge-Newton, MA-NH Metro Area    29225.0      345.0
# 110                             Boulder, CO Metro Area    28368.0      911.0
# 120         Bridgeport-Stamford-Norwalk, CT Metro Area    32385.0      674.0
# 259                             Edwards, CO Micro Area    40478.0     2582.0
# 417                          Jackson, WY-ID Micro Area    32402.0     5774.0
# 506                          Los Alamos, NM Micro Area    47250.0     8691.0
# 507      Los Angeles-Long Beach-Anaheim, CA Metro Area    24426.0      149.0
# 563                             Midland, TX Metro Area    31622.0      922.0
# 601                                Napa, CA Metro Area    32283.0     1433.0
# 602       Naples-Immokalee-Marco Island, FL Metro Area    27249.0      633.0
# 617   New York-Newark-Jersey City, NY-NJ-PA Metro Area    24732.0      148.0
# 655        Oxnard-Thousand Oaks-Ventura, CA Metro Area    34234.0      773.0
# 766       San Francisco-Oakland-Hayward, CA Metro Area    32235.0      254.0
# 768      San Jose-Sunnyvale-Santa Clara, CA Metro Area    39133.0      751.0
# 771              Santa Cruz-Watsonville, CA Metro Area    27103.0     1162.0
# 838                         Summit Park, UT Micro Area    41628.0     4384.0
# 863                             Trenton, NJ Metro Area    28705.0     1554.0
# 891                      Vineyard Haven, MA Micro Area    30057.0     3626.0
# 905  Washington-Arlington-Alexandria, DC-VA-MD-WV M...    41054.0      264.0
# 924                           Williston, ND Micro Area    36890.0     5048.0
#
#      HD01_VD03  HD02_VD03  HD01_VD04  HD02_VD04  HD01_VD05  HD02_VD05  \
# 0        55920       4923      90161       6006     146206       6942
# 109      60545        343      98251        581     154820        789
# 110      55378       1196      91056       1521     148663       2650
# 120      66551        945     110368       1393     191602       2122
# 259      66183       4343      94777       5378     139984       3936
# 417      59526       4904      85468       5229     129621       9133
# 506      88420       3310     123242       8281     177485       9948
# 507      48258        212      79542        294     130673        456
# 563      57037       2005      89892       3126     140136       4595
# 601      59536       1913      93005       2113     146169       3402
# 602      48388       1211      75034       1633     124673       2993
# 617      52321        198      88689        408     146665        569
# 655      62703        767      96565        933     149504       2298
# 766      66606        456     108268        624     176301        826
# 768      78060        936     124185        879     197391       1714
# 771      53254       1455      87408       2112     143811       2933
# 838      75092       6082     113404       6346     178286       9868
# 863      58468       1884      94460       1601     153696       2924
# 891      50209       5818      86814      11770     128389      10693
# 905      74927        364     114343        503     175691        718
# 924      73549       6423     110455       6974     160011       9265
#
#      HD01_VD06  HD02_VD06            States  \
# 0          NaN        NaN      [California]
# 109        NaN        NaN          [MA, NH]
# 110        NaN        NaN              [CO]
# 120        NaN        NaN              [CT]
# 259        NaN        NaN              [CO]
# 417        NaN        NaN          [WY, ID]
# 506        NaN        NaN              [NM]
# 507        NaN        NaN              [CA]
# 563        NaN        NaN              [TX]
# 601        NaN        NaN              [CA]
# 602        NaN        NaN              [FL]
# 617        NaN        NaN      [NY, NJ, PA]
# 655        NaN        NaN              [CA]
# 766        NaN        NaN              [CA]
# 768        NaN        NaN              [CA]
# 771        NaN        NaN              [CA]
# 838        NaN        NaN              [UT]
# 863        NaN        NaN              [NJ]
# 891        NaN        NaN              [MA]
# 905        NaN        NaN  [DC, VA, MD, WV]
# 924        NaN        NaN              [ND]
#
#                                                  PUMAS  count  95_Percentile  \
# 0                                                   {}  False            NaN
# 109  {2500400: 0.346, 2500501: 1.0, 2500502: 1.0, 2...   True       298500.0
# 110  {800801: 0.211, 800802: 0.704, 800803: 1.0, 80...   True       298000.0
# 120  {900100: 1.0, 900101: 1.0, 900102: 1.0, 900103...   True       482000.0
# 259                                     {800400: 0.46}  False       235000.0
# 417                   {1601100: 0.078, 5600100: 0.196}  False       178080.0
# 506                                   {3500300: 0.143}  False       181500.0
# 507  {603701: 1.0, 603702: 1.0, 603703: 1.0, 603704...   True       269000.0
# 563                     {4802800: 0.047, 4803000: 1.0}   True       245000.0
# 601                                      {605500: 1.0}   True       269010.0
# 602         {1202101: 1.0, 1202102: 1.0, 1202103: 1.0}   True       351400.0
# 617  {3400301: 1.0, 3400302: 1.0, 3400303: 1.0, 340...   True       302000.0
# 655  {611101: 1.0, 611102: 1.0, 611103: 1.0, 611104...   True       263200.0
# 766  {600101: 1.0, 600102: 1.0, 600103: 1.0, 600104...   True       394600.0
# 768  {605303: 0.418, 608501: 1.0, 608502: 1.0, 6085...   True       426900.0
# 771                         {608701: 1.0, 608702: 1.0}   True       342000.0
# 838                                   {4905001: 0.226}  False       334500.0
# 863         {3402301: 1.0, 3402302: 1.0, 3402303: 1.0}   True       305000.0
# 891                                   {2504800: 0.148}  False       280070.0
# 905  {1100101: 1.0, 1100102: 1.0, 1100103: 1.0, 110...   True       316230.0
# 924                                   {3800100: 0.128}  False       220000.0
#
#      20_Percentile
# 0              NaN
# 109        30300.0
# 110        30400.0
# 120        34000.0
# 259        31700.0
# 417        23000.0
# 506        11800.0
# 507        25000.0
# 563        30000.0
# 601        35000.0
# 602        28000.0
# 617        25200.0
# 655        32500.0
# 766        36000.0
# 768        41000.0
# 771        27360.0
# 838        31500.0
# 863        30000.0
# 891        32800.0
# 905        40000.0
# 924        32400.0

# %% [markdown]
# Calculate the 95/20 ratio for every CBSA in the dataset. I decided to filter down the cities I included, at this stage to only include:
#
# * Metro Areas
# * Not Puerto Rico (if you leave it in, these metro areas dominate the top of the list)
# * Population >=500,000 (mean population for metro CBSAs that are not in Puerto Rico is ~550,000)

# %%
# %matplotlib inline
import math

def ninetyfive_twenty(row):
    if row["GEO.id2"] == 640354:
        return None
    if math.isnan(row["HD01_VD06"]):
        return (row["95_Percentile"]/row["20_Percentile"])
    else:
        return (row["HD01_VD06"]/row["HD01_VD02"])
    
inequality_chart = acs_16[["GEO.id2","GEO.display-label","HD01_VD02","HD01_VD06"]].join(top_coded[["GEO.id2","95_Percentile","20_Percentile"]].set_index("GEO.id2"),on="GEO.id2")    
inequality_chart[9520] = inequality_chart.apply(lambda x: ninetyfive_twenty(x),axis=1)
pop_16 = pandas.read_csv("ACS_16_1YR_B01003.csv",encoding = "ISO-8859-1")
inequality_chart = inequality_chart.join(pop_16[["GEO.id2","HD01_VD01"]].set_index("GEO.id2"),on="GEO.id2")
inequality_chart["us_metro"] = inequality_chart.apply(lambda x: ("Metro" in x["GEO.display-label"]) & (" PR " not in x["GEO.display-label"]) & (x["HD01_VD01"] >= 500000),axis=1)

# %%
inequality_chart[inequality_chart["us_metro"]].sort_values(9520,ascending=False) ## join hte mabel population totals
# Out:
#      GEO.id2                                  GEO.display-label  HD01_VD02  \
# 120    14860         Bridgeport-Stamford-Norwalk, CT Metro Area    32385.0
# 617    35620   New York-Newark-Jersey City, NY-NJ-PA Metro Area    24732.0
# 766    41860       San Francisco-Oakland-Hayward, CA Metro Area    32235.0
# 507    31080      Los Angeles-Long Beach-Anaheim, CA Metro Area    24426.0
# 611    35380                New Orleans-Metairie, LA Metro Area    18379.0
# 768    41940      San Jose-Sunnyvale-Santa Clara, CA Metro Area    39133.0
# 559    33100  Miami-Fort Lauderdale-West Palm Beach, FL Metr...    20387.0
# 546    32580            McAllen-Edinburg-Mission, TX Metro Area    13966.0
# 253    20500                  Durham-Chapel Hill, NC Metro Area    22462.0
# 109    14460          Boston-Cambridge-Newton, MA-NH Metro Area    29225.0
# 414    27140                             Jackson, MS Metro Area    18354.0
# 395    26420    Houston-The Woodlands-Sugar Land, TX Metro Area    25337.0
# 675    37980  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD Me...    24874.0
# 321    23420                              Fresno, CA Metro Area    18645.0
# 820    44140                         Springfield, MA Metro Area    20056.0
# 552    32820                       Memphis, TN-MS-AR Metro Area    19457.0
# 168    16980      Chicago-Naperville-Elgin, IL-IN-WI Metro Area    25226.0
# 706    39300               Providence-Warwick, RI-MA Metro Area    21822.0
# 72     12940                         Baton Rouge, LA Metro Area    20376.0
# 179    17460                    Cleveland-Elyria, OH Metro Area    20224.0
# 237    19820             Detroit-Warren-Dearborn, MI Metro Area    21402.0
# 610    35300                   New Haven-Milford, CT Metro Area    24298.0
# 94     13820                   Birmingham-Hoover, AL Metro Area    20040.0
# 859    45780                              Toledo, OH Metro Area    18257.0
# 493    30460                   Lexington-Fayette, KY Metro Area    21133.0
# 16     10740                         Albuquerque, NM Metro Area    19860.0
# 171    17140                    Cincinnati, OH-KY-IN Metro Area    22823.0
# 56     12260          Augusta-Richmond County, GA-SC Metro Area    18651.0
# 565    33340       Milwaukee-Waukesha-West Allis, WI Metro Area    22385.0
# 682    38300                          Pittsburgh, PA Metro Area    21896.0
# ..       ...                                                ...        ...
# 661    37340       Palm Bay-Melbourne-Titusville, FL Metro Area    21931.0
# 775    42220                          Santa Rosa, CA Metro Area    29405.0
# 905    47900  Washington-Arlington-Alexandria, DC-VA-MD-WV M...    41054.0
# 191    17900                            Columbia, SC Metro Area    21749.0
# 818    44060              Spokane-Spokane Valley, WA Metro Area    21138.0
# 234    19740              Denver-Aurora-Lakewood, CO Metro Area    30180.0
# 441    28140                      Kansas City, MO-KS Metro Area    25624.0
# 697    38860             Portland-South Portland, ME Metro Area    26200.0
# 104    14260                          Boise City, ID Metro Area    23113.0
# 713    39580                             Raleigh, NC Metro Area    29462.0
# 941    49660       Youngstown-Warren-Boardman, OH-PA Metro Area    18802.0
# 921    48620                             Wichita, KS Metro Area    22410.0
# 567    33460  Minneapolis-St. Paul-Bloomington, MN-WI Metro ...    30843.0
# 12     10580             Albany-Schenectady-Troy, NY Metro Area    26641.0
# 232    19660  Deltona-Daytona Beach-Ormond Beach, FL Metro Area    19932.0
# 21     10900       Allentown-Bethlehem-Easton, PA-NJ Metro Area    26532.0
# 638    36540             Omaha-Council Bluffs, NE-IA Metro Area    26152.0
# 478    29820        Las Vegas-Henderson-Paradise, NV Metro Area    23903.0
# 236    19780          Des Moines-West Des Moines, IA Metro Area    28280.0
# 518    31540                             Madison, WI Metro Area    28189.0
# 189    17820                    Colorado Springs, CO Metro Area    27187.0
# 470    29460               Lakeland-Winter Haven, FL Metro Area    20442.0
# 892    47260  Virginia Beach-Norfolk-Newport News, VA-NC Met...    26636.0
# 343    24340                Grand Rapids-Wyoming, MI Metro Area    25192.0
# 369    25420                 Harrisburg-Carlisle, PA Metro Area    26911.0
# 759    41620                      Salt Lake City, UT Metro Area    30130.0
# 876    46520                      Urban Honolulu, HI Metro Area    34849.0
# 472    29540                           Lancaster, PA Metro Area    27631.0
# 707    39340                          Provo-Orem, UT Metro Area    30531.0
# 631    36260                    Ogden-Clearfield, UT Metro Area    32163.0
#
#      HD01_VD06  95_Percentile  20_Percentile       9520   HD01_VD01  us_metro
# 120        NaN       482000.0        34000.0  14.176471    944177.0      True
# 617        NaN       302000.0        25200.0  11.984127  20153634.0      True
# 766        NaN       394600.0        36000.0  10.961111   4679166.0      True
# 507        NaN       269000.0        25000.0  10.760000  13310447.0      True
# 611   194587.0            NaN            NaN  10.587464   1268883.0      True
# 768        NaN       426900.0        41000.0  10.412195   1978816.0      True
# 559   209733.0            NaN            NaN  10.287585   6066387.0      True
# 546   143137.0            NaN            NaN  10.248962    849843.0      True
# 253   228650.0            NaN            NaN  10.179414    559535.0      True
# 109        NaN       298500.0        30300.0   9.851485   4794447.0      True
# 414   179805.0            NaN            NaN   9.796502    580178.0      True
# 395   243272.0            NaN            NaN   9.601452   6772470.0      True
# 675   238342.0            NaN            NaN   9.581973   6070500.0      True
# 321   175682.0            NaN            NaN   9.422473    979915.0      True
# 820   188399.0            NaN            NaN   9.393648    630283.0      True
# 552   182743.0            NaN            NaN   9.392147   1346437.0      True
# 168   236008.0            NaN            NaN   9.355744   9512968.0      True
# 706   203618.0            NaN            NaN   9.330859   1614750.0      True
# 72    189667.0            NaN            NaN   9.308353    835175.0      True
# 179   187912.0            NaN            NaN   9.291535   2055612.0      True
# 237   198271.0            NaN            NaN   9.264134   4297617.0      True
# 610   222312.0            NaN            NaN   9.149395    856875.0      True
# 94    183076.0            NaN            NaN   9.135529   1147417.0      True
# 859   166568.0            NaN            NaN   9.123514    605221.0      True
# 493   192319.0            NaN            NaN   9.100412    506751.0      True
# 16    178817.0            NaN            NaN   9.003877    913924.0      True
# 171   203361.0            NaN            NaN   8.910354   2161441.0      True
# 56    165035.0            NaN            NaN   8.848587    595147.0      True
# 565   197834.0            NaN            NaN   8.837793   1572482.0      True
# 682   192752.0            NaN            NaN   8.803069   2342299.0      True
# ..         ...            ...            ...        ...         ...       ...
# 661   173907.0            NaN            NaN   7.929734    579130.0      True
# 775   232768.0            NaN            NaN   7.915933    503070.0      True
# 905        NaN       316230.0        40000.0   7.905750   6133552.0      True
# 191   171737.0            NaN            NaN   7.896317    816450.0      True
# 818   166713.0            NaN            NaN   7.886886    556264.0      True
# 234   236836.0            NaN            NaN   7.847449   2853077.0      True
# 441   199509.0            NaN            NaN   7.786021   2104115.0      True
# 697   202202.0            NaN            NaN   7.717634    529657.0      True
# 104   177996.0            NaN            NaN   7.701121    690214.0      True
# 713   225416.0            NaN            NaN   7.651076   1302946.0      True
# 941   143195.0            NaN            NaN   7.615945    544746.0      True
# 921   170567.0            NaN            NaN   7.611200    645447.0      True
# 567   232836.0            NaN            NaN   7.549071   3551036.0      True
# 12    200971.0            NaN            NaN   7.543673    881839.0      True
# 232   149308.0            NaN            NaN   7.490869    637674.0      True
# 21    198437.0            NaN            NaN   7.479157    835652.0      True
# 638   194121.0            NaN            NaN   7.422797    924495.0      True
# 478   176075.0            NaN            NaN   7.366230   2155664.0      True
# 236   206520.0            NaN            NaN   7.302687    634725.0      True
# 518   204623.0            NaN            NaN   7.258966    648929.0      True
# 189   195943.0            NaN            NaN   7.207231    712327.0      True
# 470   145986.0            NaN            NaN   7.141473    666149.0      True
# 892   190160.0            NaN            NaN   7.139210   1725937.0      True
# 343   176786.0            NaN            NaN   7.017545   1047099.0      True
# 369   187361.0            NaN            NaN   6.962246    568033.0      True
# 759   207084.0            NaN            NaN   6.873017   1186187.0      True
# 876   237557.0            NaN            NaN   6.816752    992605.0      True
# 472   180604.0            NaN            NaN   6.536282    538500.0      True
# 707   188019.0            NaN            NaN   6.158298    602543.0      True
# 631   179320.0            NaN            NaN   5.575351    656061.0      True
#
# [107 rows x 9 columns]

# %%
def consolidate(row,col_tuple):
    first = row[col_tuple[0]]
    if math.isnan(first):
        return row[col_tuple[1]]
    else:
        return first

to_export = inequality_chart[inequality_chart["us_metro"]]
to_export["95"] = to_export.apply(lambda x: consolidate(x,("HD01_VD06","95_Percentile")),axis=1)
to_export["20"] = to_export.apply(lambda x: consolidate(x,("HD01_VD02","20_Percentile")),axis=1)
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
to_export = to_export.rename(columns={"HD01_VD01":"pop_estimate"})
to_export = to_export[["GEO.id2","GEO.display-label","95","20",9520,"pop_estimate"]].sort_values(9520,ascending=False)
to_export.to_csv("95-20-MSA.csv")
to_export
# Out:
#      GEO.id2                                  GEO.display-label        95  \
# 120    14860         Bridgeport-Stamford-Norwalk, CT Metro Area  482000.0
# 617    35620   New York-Newark-Jersey City, NY-NJ-PA Metro Area  302000.0
# 766    41860       San Francisco-Oakland-Hayward, CA Metro Area  394600.0
# 507    31080      Los Angeles-Long Beach-Anaheim, CA Metro Area  269000.0
# 611    35380                New Orleans-Metairie, LA Metro Area  194587.0
# 768    41940      San Jose-Sunnyvale-Santa Clara, CA Metro Area  426900.0
# 559    33100  Miami-Fort Lauderdale-West Palm Beach, FL Metr...  209733.0
# 546    32580            McAllen-Edinburg-Mission, TX Metro Area  143137.0
# 253    20500                  Durham-Chapel Hill, NC Metro Area  228650.0
# 109    14460          Boston-Cambridge-Newton, MA-NH Metro Area  298500.0
# 414    27140                             Jackson, MS Metro Area  179805.0
# 395    26420    Houston-The Woodlands-Sugar Land, TX Metro Area  243272.0
# 675    37980  Philadelphia-Camden-Wilmington, PA-NJ-DE-MD Me...  238342.0
# 321    23420                              Fresno, CA Metro Area  175682.0
# 820    44140                         Springfield, MA Metro Area  188399.0
# 552    32820                       Memphis, TN-MS-AR Metro Area  182743.0
# 168    16980      Chicago-Naperville-Elgin, IL-IN-WI Metro Area  236008.0
# 706    39300               Providence-Warwick, RI-MA Metro Area  203618.0
# 72     12940                         Baton Rouge, LA Metro Area  189667.0
# 179    17460                    Cleveland-Elyria, OH Metro Area  187912.0
# 237    19820             Detroit-Warren-Dearborn, MI Metro Area  198271.0
# 610    35300                   New Haven-Milford, CT Metro Area  222312.0
# 94     13820                   Birmingham-Hoover, AL Metro Area  183076.0
# 859    45780                              Toledo, OH Metro Area  166568.0
# 493    30460                   Lexington-Fayette, KY Metro Area  192319.0
# 16     10740                         Albuquerque, NM Metro Area  178817.0
# 171    17140                    Cincinnati, OH-KY-IN Metro Area  203361.0
# 56     12260          Augusta-Richmond County, GA-SC Metro Area  165035.0
# 565    33340       Milwaukee-Waukesha-West Allis, WI Metro Area  197834.0
# 682    38300                          Pittsburgh, PA Metro Area  192752.0
# ..       ...                                                ...       ...
# 661    37340       Palm Bay-Melbourne-Titusville, FL Metro Area  173907.0
# 775    42220                          Santa Rosa, CA Metro Area  232768.0
# 905    47900  Washington-Arlington-Alexandria, DC-VA-MD-WV M...  316230.0
# 191    17900                            Columbia, SC Metro Area  171737.0
# 818    44060              Spokane-Spokane Valley, WA Metro Area  166713.0
# 234    19740              Denver-Aurora-Lakewood, CO Metro Area  236836.0
# 441    28140                      Kansas City, MO-KS Metro Area  199509.0
# 697    38860             Portland-South Portland, ME Metro Area  202202.0
# 104    14260                          Boise City, ID Metro Area  177996.0
# 713    39580                             Raleigh, NC Metro Area  225416.0
# 941    49660       Youngstown-Warren-Boardman, OH-PA Metro Area  143195.0
# 921    48620                             Wichita, KS Metro Area  170567.0
# 567    33460  Minneapolis-St. Paul-Bloomington, MN-WI Metro ...  232836.0
# 12     10580             Albany-Schenectady-Troy, NY Metro Area  200971.0
# 232    19660  Deltona-Daytona Beach-Ormond Beach, FL Metro Area  149308.0
# 21     10900       Allentown-Bethlehem-Easton, PA-NJ Metro Area  198437.0
# 638    36540             Omaha-Council Bluffs, NE-IA Metro Area  194121.0
# 478    29820        Las Vegas-Henderson-Paradise, NV Metro Area  176075.0
# 236    19780          Des Moines-West Des Moines, IA Metro Area  206520.0
# 518    31540                             Madison, WI Metro Area  204623.0
# 189    17820                    Colorado Springs, CO Metro Area  195943.0
# 470    29460               Lakeland-Winter Haven, FL Metro Area  145986.0
# 892    47260  Virginia Beach-Norfolk-Newport News, VA-NC Met...  190160.0
# 343    24340                Grand Rapids-Wyoming, MI Metro Area  176786.0
# 369    25420                 Harrisburg-Carlisle, PA Metro Area  187361.0
# 759    41620                      Salt Lake City, UT Metro Area  207084.0
# 876    46520                      Urban Honolulu, HI Metro Area  237557.0
# 472    29540                           Lancaster, PA Metro Area  180604.0
# 707    39340                          Provo-Orem, UT Metro Area  188019.0
# 631    36260                    Ogden-Clearfield, UT Metro Area  179320.0
#
#           20       9520  pop_estimate
# 120  32385.0  14.176471      944177.0
# 617  24732.0  11.984127    20153634.0
# 766  32235.0  10.961111     4679166.0
# 507  24426.0  10.760000    13310447.0
# 611  18379.0  10.587464     1268883.0
# 768  39133.0  10.412195     1978816.0
# 559  20387.0  10.287585     6066387.0
# 546  13966.0  10.248962      849843.0
# 253  22462.0  10.179414      559535.0
# 109  29225.0   9.851485     4794447.0
# 414  18354.0   9.796502      580178.0
# 395  25337.0   9.601452     6772470.0
# 675  24874.0   9.581973     6070500.0
# 321  18645.0   9.422473      979915.0
# 820  20056.0   9.393648      630283.0
# 552  19457.0   9.392147     1346437.0
# 168  25226.0   9.355744     9512968.0
# 706  21822.0   9.330859     1614750.0
# 72   20376.0   9.308353      835175.0
# 179  20224.0   9.291535     2055612.0
# 237  21402.0   9.264134     4297617.0
# 610  24298.0   9.149395      856875.0
# 94   20040.0   9.135529     1147417.0
# 859  18257.0   9.123514      605221.0
# 493  21133.0   9.100412      506751.0
# 16   19860.0   9.003877      913924.0
# 171  22823.0   8.910354     2161441.0
# 56   18651.0   8.848587      595147.0
# 565  22385.0   8.837793     1572482.0
# 682  21896.0   8.803069     2342299.0
# ..       ...        ...           ...
# 661  21931.0   7.929734      579130.0
# 775  29405.0   7.915933      503070.0
# 905  41054.0   7.905750     6133552.0
# 191  21749.0   7.896317      816450.0
# 818  21138.0   7.886886      556264.0
# 234  30180.0   7.847449     2853077.0
# 441  25624.0   7.786021     2104115.0
# 697  26200.0   7.717634      529657.0
# 104  23113.0   7.701121      690214.0
# 713  29462.0   7.651076     1302946.0
# 941  18802.0   7.615945      544746.0
# 921  22410.0   7.611200      645447.0
# 567  30843.0   7.549071     3551036.0
# 12   26641.0   7.543673      881839.0
# 232  19932.0   7.490869      637674.0
# 21   26532.0   7.479157      835652.0
# 638  26152.0   7.422797      924495.0
# 478  23903.0   7.366230     2155664.0
# 236  28280.0   7.302687      634725.0
# 518  28189.0   7.258966      648929.0
# 189  27187.0   7.207231      712327.0
# 470  20442.0   7.141473      666149.0
# 892  26636.0   7.139210     1725937.0
# 343  25192.0   7.017545     1047099.0
# 369  26911.0   6.962246      568033.0
# 759  30130.0   6.873017     1186187.0
# 876  34849.0   6.816752      992605.0
# 472  27631.0   6.536282      538500.0
# 707  30531.0   6.158298      602543.0
# 631  32163.0   5.575351      656061.0
#
# [107 rows x 6 columns]

# %% [markdown]
# # Qunitile Wages 2007-2016
#
# Fetch mean wages 2011-2016 for the bottom 20% and the top 5% of the US and of Bridgeport-Stamford-Norwalk from the Census API -- American Commmunity Survey 1-year

# %%
import pandas,json,urllib,re,numpy,time

base = "https://api.census.gov/data/"


fields = ["B19081_001E","B19081_006E"]
year_range = [2012,2016]

def construct_quint_url(year,geo_type,geo_code,quints):
    url = base
    if (year == 2016):
        url += str(year)+"/acs/acs1?get="
    else:
        url += str(year)+"/acs1?get="
    i=1 
    for quint in quints:
        url += quint+"&"
        i+=1
    url+= "for="+geo_type+geo_code
    return(url)

def url_to_data(url):
    req = urllib.request.Request(url)
    req.add_header('User-agent', 'Mozilla 5.10')
    res = urllib.request.urlopen(req)
    data = json.load(res)
    return data

def make_long_data(date_r, geo_type, geo_code,quints):
    year = date_r[0]
    tar = [fields+["geo","year"]]
    while year <= date_r[1]:
        print(construct_quint_url(year,geo_type,geo_code,quints))
        new_row = url_to_data(construct_quint_url(year,geo_type,geo_code,quints))[1]
        new_row.append(year)
        tar.append(new_row)
        year += 1
    return tar

bridgeport_data = make_long_data(year_range,"metropolitan%20statistical%20area/micropolitan%20statistical%20area",":14860",fields)
national_data = make_long_data(year_range,"us","",fields)
# Out:
# https://api.census.gov/data/2012/acs1?get=B19081_001E&B19081_006E&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:14860
# https://api.census.gov/data/2013/acs1?get=B19081_001E&B19081_006E&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:14860
# https://api.census.gov/data/2014/acs1?get=B19081_001E&B19081_006E&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:14860
# https://api.census.gov/data/2015/acs1?get=B19081_001E&B19081_006E&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:14860
# https://api.census.gov/data/2016/acs/acs1?get=B19081_001E&B19081_006E&for=metropolitan%20statistical%20area/micropolitan%20statistical%20area:14860
# https://api.census.gov/data/2012/acs1?get=B19081_001E&B19081_006E&for=us
# https://api.census.gov/data/2013/acs1?get=B19081_001E&B19081_006E&for=us
# https://api.census.gov/data/2014/acs1?get=B19081_001E&B19081_006E&for=us
# https://api.census.gov/data/2015/acs1?get=B19081_001E&B19081_006E&for=us
# https://api.census.gov/data/2016/acs/acs1?get=B19081_001E&B19081_006E&for=us

# %%
#ct_data = make_long_data(year_range,"state",":009",fields)
bridgeport_data
# Out:
# [['B19081_001E', 'B19081_006E', 'geo', 'year'],
#  ['15822', '768432', '14860', 2012],
#  ['15817', '781504', '14860', 2013],
#  ['16741', '822518', '14860', 2014],
#  ['16544', '777935', '14860', 2015],
#  ['18159', '813869', '14860', 2016]]

# %%
bp_df = pandas.DataFrame(bridgeport_data[1:],columns = bridgeport_data[0])
nat_df = pandas.DataFrame(national_data[1:],columns = national_data[0])

bp_df = bp_df.rename(columns={"B19081_001E":"20","B19081_006E":"95"})
nat_df = nat_df.rename(columns={"B19081_001E":"20","B19081_006E":"95"})

# %% [markdown]
# Import the manually-collected data from before 2011, taken from the American Community Survey "Fact Finder" website, join with our API data.

# %%
bp_df = bp_df[bp_df.columns[bp_df.columns!="geo"]]
nat_df = nat_df[nat_df.columns[nat_df.columns!="geo"]]
df = bp_df.join(nat_df.set_index("year"),on="year",lsuffix="_BP",rsuffix="_US")
earlier_years = pandas.read_csv("excel/pre2011.csv")
join_df = earlier_years.rename(columns = {"BP_20":"20_BP","BP_95":"95_BP","US_20":"20_US","US_95":"95_US"})
join_df = join_df[["year","20_BP","95_BP","20_US","95_US"]]

df = pandas.concat([join_df,df]).sort_values("year").reset_index(drop=True)

# %% [markdown]
# Adjust for inflation, using the Consumer Price Index.

# %%
cpi = pandas.read_csv("excel/consumer_price_index.csv").set_index("year")
to_adjust = df.join(cpi,on="year")
cols = to_adjust.columns
to_adjust[cols] = to_adjust[cols].apply(pandas.to_numeric, errors='coerce')
to_adjust
# Out:
#    20_BP  20_US   95_BP   95_US  year    CPI
# 0  18166  11797  743831  311427  2007  304.6
# 1  16701  11984  822708  322881  2008  316.3
# 2  16145  11467  700068  305979  2009  315.2
# 3  14933  11307  685431  299770  2010  320.3
# 4  15286  11186  669517  311995  2011  330.5
# 5  15822  11361  768432  319918  2012  337.3
# 6  15817  11544  781504  339950  2013  342.2
# 7  16741  11859  822518  346522  2014  347.8
# 8  16544  12365  777935  364563  2015  348.2
# 9  18159  12691  813869  378330  2016  352.6

# %%
# Inflation-adjusted estimate = 1995 estimate * (2016 CPI-U-RS / 1995 CPI-U-RS)
#                        = 1995 estimate * (352.6 / 225)

adjustable_cols = ["20_BP", "20_US", "95_BP", "95_US"]

def adjust_dollars(row,base_cpi):
    factor = base_cpi/row["CPI"]
    tar = {}
    for x in adjustable_cols:
        tar[x] = row[x]*factor
    tar["year"] = row["year"]
    return tar

adjusted = to_adjust.copy()

adjusted["2016_dollars"] = adjusted.apply(lambda x: adjust_dollars(x,cpi.loc[2016]["CPI"]),axis=1)
adjusted["2007_dollars"] = adjusted.apply(lambda x: adjust_dollars(x,cpi.loc[2007]["CPI"]),axis=1)

# %%
sixteen_dollars = pandas.DataFrame(adjusted["2016_dollars"].tolist())
seven_dollars = pandas.DataFrame(adjusted["2007_dollars"].tolist())

# %%
sixteen_dollars
# Out:
#           20_BP         20_US          95_BP          95_US    year
# 0  21028.665791  13656.015102  861046.653316  360502.824032  2007.0
# 1  18617.681315  13359.337338  917125.642744  359936.264938  2008.0
# 2  18060.682107  12827.614848  783134.444162  342284.883883  2009.0
# 3  16438.887918  12447.231346  754551.890727  329999.694037  2010.0
# 4  16308.150076  11933.989713  714286.518003  332857.600605  2011.0
# 5  16539.689297  11876.337385  803288.239549  334429.548770  2012.0
# 6  16297.703682  11894.840444  805255.144360  350281.618936  2013.0
# 7  16972.043128  12022.666475  833869.599770  351304.362277  2014.0
# 8  16753.056864  12521.249282  787765.310167  369169.769673  2015.0
# 9  18159.000000  12691.000000  813869.000000  378330.000000  2016.0

# %%
to_adjust
# Out:
#    20_BP  20_US   95_BP   95_US  year    CPI
# 0  18166  11797  743831  311427  2007  304.6
# 1  16701  11984  822708  322881  2008  316.3
# 2  16145  11467  700068  305979  2009  315.2
# 3  14933  11307  685431  299770  2010  320.3
# 4  15286  11186  669517  311995  2011  330.5
# 5  15822  11361  768432  319918  2012  337.3
# 6  15817  11544  781504  339950  2013  342.2
# 7  16741  11859  822518  346522  2014  347.8
# 8  16544  12365  777935  364563  2015  348.2
# 9  18159  12691  813869  378330  2016  352.6

# %% [markdown]
# Zero-index the data to track percent change since 2007.

# %%
def index(row,base_row):
    tar = {}
    for x in adjustable_cols:
        tar[x] = ((row[x]/base_row[x]) * 100) - 100
    tar["year"] = row["year"]
    return(tar)

base_index = adjusted.loc[0]
adjusted["index"] = adjusted.apply(lambda x: index(x,base_index),axis=1)

# %%
current_dollars_indexed = pandas.DataFrame(adjusted["index"].tolist())
print(current_dollars_indexed)
current_dollars_indexed.set_index("year").plot(title="Indexed % change in income: 20, 95, US, Bridgeport\n(Not adjusted for inflation)")
# Out:
#        20_BP     20_US      95_BP      95_US  year
# 0   0.000000  0.000000   0.000000   0.000000  2007
# 1  -8.064516  1.585149  10.604156   3.677908  2008
# 2 -11.125179 -2.797321  -5.883460  -1.749367  2009
# 3 -17.796983 -4.153598  -7.851246  -3.743092  2010
# 4 -15.853793 -5.179283  -9.990710   0.182386  2011
# 5 -12.903226 -3.695855   3.307337   2.726482  2012
# 6 -12.930750 -2.144613   5.064726   9.158808  2013
# 7  -7.844325  0.525557  10.578613  11.269094  2014
# 8  -8.928768  4.814783   4.584912  17.062104  2015
# 9  -0.038534  7.578198   9.415848  21.482723  2016

# %% [markdown]
# It turns out things look different if we adjust the indexed analysis for inflation! It doesn't matter whether we index by the beginning of our data set or the end, which I expected, which is good.

# %%
base_index = seven_dollars.loc[0]
seven_dollars["index"] = seven_dollars.apply(lambda x: index(x,base_index),axis=1)

seven_dollars_indexed = pandas.DataFrame(seven_dollars["index"].tolist())
print(seven_dollars_indexed)
seven_dollars_indexed.set_index("year").plot(title="Indexed % change in income: 20, 95, US, Bridgeport\n(Inflation-adjusted)")
# Out:
#        20_BP      20_US      95_BP     95_US    year
# 0   0.000000   0.000000   0.000000  0.000000  2007.0
# 1 -11.465228  -2.172506   6.512886 -0.157158  2008.0
# 2 -14.113990  -6.066193  -9.048547 -5.053481  2009.0
# 3 -21.826291  -8.851658 -12.368060 -8.461274  2010.0
# 4 -22.448004 -12.610014 -17.044388 -7.668518  2011.0
# 5 -21.346939 -13.032189  -6.707931 -7.232475  2012.0
# 6 -22.497681 -12.896695  -6.479499 -2.835264  2013.0
# 7 -19.290918 -11.960653  -3.156281 -2.551564  2014.0
# 8 -20.332288  -8.309641  -8.510729  2.404127  2015.0
# 9 -13.646447  -7.066594  -5.479105  4.945086  2016.0

# %%
sixteen_base_index = sixteen_dollars.loc[0]
      
sixteen_dollars["index"] = sixteen_dollars.apply(lambda x: index(x,sixteen_base_index),axis=1)

sixteen_dollars_indexed = pandas.DataFrame(sixteen_dollars["index"].tolist())
print(sixteen_dollars_indexed)
sixteen_dollars_indexed.set_index("year").plot(title="Indexed % change in income: 20, 95, US, Bridgeport\n(Inflation-adjusted)")
# Out:
#        20_BP      20_US      95_BP     95_US    year
# 0   0.000000   0.000000   0.000000  0.000000  2007.0
# 1 -11.465228  -2.172506   6.512886 -0.157158  2008.0
# 2 -14.113990  -6.066193  -9.048547 -5.053481  2009.0
# 3 -21.826291  -8.851658 -12.368060 -8.461274  2010.0
# 4 -22.448004 -12.610014 -17.044388 -7.668518  2011.0
# 5 -21.346939 -13.032189  -6.707931 -7.232475  2012.0
# 6 -22.497681 -12.896695  -6.479499 -2.835264  2013.0
# 7 -19.290918 -11.960653  -3.156281 -2.551564  2014.0
# 8 -20.332288  -8.309641  -8.510729  2.404127  2015.0
# 9 -13.646447  -7.066594  -5.479105  4.945086  2016.0

# %%
import json

sixteen_j = json.loads(sixteen_dollars_indexed.set_index("year").transpose().to_json(orient='split'))

print(json.dumps(sixteen_j,indent=2))
# Out:
# {
#   "columns": [
#     2007.0,
#     2008.0,
#     2009.0,
#     2010.0,
#     2011.0,
#     2012.0,
#     2013.0,
#     2014.0,
#     2015.0,
#     2016.0
#   ],
#   "index": [
#     "20_BP",
#     "20_US",
#     "95_BP",
#     "95_US"
#   ],
#   "data": [
#     [
#       0.0,
#       -11.4652279889,
#       -14.1139895135,
#       -21.8262914024,
#       -22.4480038935,
#       -21.3469391659,
#       -22.497680814,
#       -19.2909179462,
#       -20.3322881717,
#       -13.6464472815
#     ],
#     [
#       0.0,
#       -2.1725061198,
#       -6.0661931602,
#       -8.8516580214,
#       -12.6100138026,
#       -13.0321891371,
#       -12.8966952985,
#       -11.960653343,
#       -8.309640926,
#       -7.0665936921
#     ],
#     [
#       0.0,
#       6.5128862893,
#       -9.0485467719,
#       -12.3680595213,
#       -17.0443883322,
#       -6.7079308123,
#       -6.4794989611,
#       -3.1562811889,
#       -8.5107285264,
#       -5.4791053579
#     ],
#     [
#       0.0,
#       -0.157158018,
#       -5.0534805649,
#       -8.4612735217,
#       -7.6685178544,
#       -7.2324746226,
#       -2.8352635302,
#       -2.5515644098,
#       2.4041269758,
#       4.9450863572
#     ]
#   ]
# }

# %%
sixteen_dollars_indexed.set_index("year").transpose().to_json('indexed_means.json',orient='split')

# %%
sixteen_dollars_indexed.set_index("year").to_csv("indexed_means.csv")

# %% [markdown]
# # State-Level 95/20
#
# Some of the state top-5% income cut-offs are also top-coded

# %%
import pandas
state_acs = pandas.read_csv("state_hh_16.csv")

# %%
top_state = state_acs[state_acs["HD01_VD06"].isnull()]
top_state
# Out:
#          GEO.id  GEO.id2     GEO.display-label  HD01_VD02  HD02_VD02  \
# 4   0400000US06        6            California      26697        183
# 6   0400000US09        9           Connecticut      29917        766
# 8   0400000US11       11  District of Columbia      20813       1543
# 20  0400000US24       24              Maryland      32691        672
# 21  0400000US25       25         Massachusetts      28024        700
# 30  0400000US34       34            New Jersey      29167        557
# 32  0400000US36       36              New York      23187        310
# 46  0400000US51       51              Virginia      28532        601
#
#     HD01_VD03  HD02_VD03  HD01_VD04  HD02_VD04  HD01_VD05  HD02_VD05  \
# 4       52331        208      85740        375     140784        465
# 6       56803        903      92131       1060     146556       1434
# 8       55236       3374     100336       2633     170657       4812
# 20      61983        611      97193        851     150178       1245
# 21      57438        786      95015        800     149866       1397
# 30      58784        674      96144        928     154189       1324
# 32      48100        521      80699        409     132453        858
# 46      53162        733      85471        567     136562        959
#
#     HD01_VD06  HD02_VD06
# 4         NaN        NaN
# 6         NaN        NaN
# 8         NaN        NaN
# 20        NaN        NaN
# 21        NaN        NaN
# 30        NaN        NaN
# 32        NaN        NaN
# 46        NaN        NaN

# %%
state_fips = {6:"ca",9:"ct",11:"dc",24:"md",25:"ma",34:"nj",36:"ny",51:"va"}

def get_state_data(year, state):
    filepath = make_path(year,state)
    census = pandas.read_csv(filepath)
    census["HHINC"] = pandas.to_numeric(census["HINCP"],errors="coerce")
    return census
    
def get_state_quantile(ss, year, percent):
    state_data = get_state_data(year, ss)
    print(state_data.head())
    exploded_state = explode_weights(state_data.head(),"HHINC","WGTP","PUMA")
    print(exploded_state.head())
    return exploded_state["HHINC"].quantile(percent)

# %%
top_state["95"] = top_state["GEO.id2"].head(1).apply(lambda x: get_state_quantile(state_fips[x],2016,.95))
# Out:
#   RT  SERIALNO  ST  DIVISION   PUMA  REGION   ADJHSG   ADJINC  WGTP  NP  \
# 0  H        33   6         9  10702       4  1000000  1007588   102   2
# 1  H        36   6         9   6514       4  1000000  1007588   122   3
# 2  H        43   6         9   3759       4  1000000  1007588    58   2
# 3  H        51   6         9   5917       4  1000000  1007588    73   2
# 4  H        52   6         9   3739       4  1000000  1007588    52   2
#
#      ...     wgtp72  wgtp73  wgtp74  wgtp75  wgtp76  wgtp77  wgtp78  wgtp79  \
# 0    ...         79      39     210     112     136     164     107     146
# 1    ...        149     227      38      35     150     116     192     156
# 2    ...         56      57      64      16      60      53      50     105
# 3    ...         66      20      22      72     108      20     129      73
# 4    ...         15      90      55      53      49      86      54      50
#
#    wgtp80     HHINC
# 0      41   54000.0
# 1     132   41500.0
# 2      15  204000.0
# 3      74  130000.0
# 4      15   76000.0
#
# [5 rows x 231 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-330a47d70a27> in <module>()
# ----> 1 top_state["95"] = top_state["GEO.id2"].head(1).apply(lambda x: get_state_quantile(state_fips[x],2016,.95))
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-54-330a47d70a27> in <lambda>(x)
# ----> 1 top_state["95"] = top_state["GEO.id2"].head(1).apply(lambda x: get_state_quantile(state_fips[x],2016,.95))
#
# <ipython-input-53-2e43394da27b> in get_state_quantile(ss, year, percent)
#      11     print(state_data.head())
#      12     exploded_state = explode_weights(state_data.head(),"HHINC","WGTP","PUMA")
# ---> 13     print(exploded_state.head())
#      14     return exploded_state["HHINC"].quantile(percent)
#
# AttributeError: 'list' object has no attribute 'head'
